# %%
arr = [2, 1, 8, 9, 12, 15, 11, 19]

# %%
arr[4]
# Out:
# 12

# %%
try:
    print(arr.index(14))
except ValueError as e:
    print(e)
# Out:
# 14 is not in list

# %%
arr
# Out:
# [2, 1, 8, 9, 12, 15, 11, 19]

# %%
# Insert an element at index 2
arr.insert(5, 2)

# %%
arr[0].__add__
# Out:
# <method-wrapper '__add__' of int object at 0x00007FFD1A8273C8>

# %%
# remove element from an array
arr.remove(8)

# %%
arr
# Out:
# [2, 1, 9, 12, 2, 15, 11, 19]

# %%
arr.count(2)
# Out:
# 2

# %%
arr.pop(1)
# Out:
# 1

# %%
arr.sort()

# %%
arr
# Out:
# [2, 2, 9, 11, 12, 15, 19]

# %%
arr.reverse()

# %%
arr
# Out:
# [19, 15, 12, 11, 9, 2, 2]
